# %% [markdown]
# # Objective
#
# To create a simple model that can predict which medication from a given list
# would be appropriate for a patient based on their symptoms/goals.

# %%
# !pip install pandas
# !pip install datasets

#press ESC to enter command mode

# %%
import os
import re
import glob
import shutil
import string
import pathlib


data_dir = os.path.abspath(os.path.join(os.getcwd(),'..','data'))


os.environ['MPLCONFIGDIR'] = os.path.join(data_dir,'plt_configs')
import matplotlib.pyplot as plt


os.environ['HF_HOME'] = os.path.join(data_dir,'hf_cache')
import datasets

import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras.layers import TextVectorization

# %% [markdown]
# # Data collection
#
# Drug review dataset obtained from Hugging Face

# %%
dataset = datasets.load_dataset("flxclxc/encoded_drug_reviews")
# Out:
# Using custom data configuration flxclxc--encoded_drug_reviews-ee0cdba36988e67d
# Found cached dataset json (/tf/data/hf_cache/datasets/flxclxc___json/flxclxc--encoded_drug_reviews-ee0cdba36988e67d/0.0.0/e6070c77f18f01a5ad4551a8b7edfba20b8438b7cad4d94e6ad9378022ce4aab)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df = pd.DataFrame(dataset)

# %%
print(df)
# Out:
#                                                    train
# 0      {'patient_id': 184648, 'drugName': 'Efudex', '...
# 1      {'patient_id': 25268, 'drugName': 'Flector Pat...
# 2      {'patient_id': 172019, 'drugName': 'Amitiza', ...
# 3      {'patient_id': 196063, 'drugName': 'Stendra', ...
# 4      {'patient_id': 225264, 'drugName': 'Bupropion'...
# ...                                                  ...
# 53466  {'patient_id': 199190, 'drugName': 'Depo-Prove...
# 53467  {'patient_id': 188476, 'drugName': 'ParaGard',...
# 53468  {'patient_id': 105752, 'drugName': 'Methylpred...
# 53469  {'patient_id': 56713, 'drugName': 'Meclizine',...
# 53470  {'patient_id': 215006, 'drugName': 'Fluoxetine...
#
# [53471 rows x 1 columns]

# %%
complete_dataset = dataset['train'].to_pandas()
complete_dataset.head()
# Out:
#    patient_id       drugName                 condition  \
# 0      184648         Efudex      basal cell carcinoma
# 1       25268  Flector Patch                      pain
# 2      172019        Amitiza  irritable bowel syndrome
# 3      196063        Stendra      erectile dysfunction
# 4      225264      Bupropion                depression
#
#                                               review  rating  \
# 0  "I have BCC on my upper arm and SCC on upper l...     1.0
# 1  "I tore my shoulder labrum and the pain can be...     8.0
# 2             "Amitiza is the best if you have ibs!"    10.0
# 3  "Viagra works in a strong, crude way with side...    10.0
# 4  "I really wanted Wellbutrin to work. I was giv...     3.0
#
#                 date  usefulCount  review_length  \
# 0    August 30, 2016           16             36
# 1       May 29, 2014           40             45
# 2      July 13, 2016            9              8
# 3  November 10, 2014           82            141
# 4    October 4, 2015           15             62
#
#                                              encoded
# 0  [-0.0633561835, 0.0115883639, -0.0027463636, 0...
# 1  [-0.083280459, 0.0182377025, 0.0619471855, 0.0...
# 2  [-0.0300639421, -0.0081300493, 0.0343461707, 0...
# 3  [-0.0037669495, -0.0845683292, 0.0196341239, 0...
# 4  [-0.0633124188, 0.0167291258, 0.0707527027, 0....

# %%
print(df.info()) # 53,471 total drug reviews in dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53471 entries, 0 to 53470
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   train   53471 non-null  object
# dtypes: object(1)
# memory usage: 417.9+ KB
# None

# %%
complete_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53471 entries, 0 to 53470
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   patient_id     53471 non-null  int64
#  1   drugName       53471 non-null  object
#  2   condition      53471 non-null  object
#  3   review         53471 non-null  object
#  4   rating         53471 non-null  float64
#  5   date           53471 non-null  object
#  6   usefulCount    53471 non-null  int64
#  7   review_length  53471 non-null  int64
#  8   encoded        53471 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 3.7+ MB

# %% [markdown]
# # Data Cleaning
#
# -Isolated drugs from the dataset with review counts > 200

# %%
# unique values in column "drugName"
drugs = complete_dataset['drugName'].unique()
for drug in drugs:
    print(drug)
# Out:
# Efudex
# Flector Patch
# Amitiza
# Stendra
# Bupropion
# Amiodarone
# Sprintec
# Acetaminophen / tramadol
# Sertraline
# Lisinopril
# Levonorgestrel
# Liraglutide
# Fluoxetine
# Methylprednisolone
# Doxylamine / pyridoxine
# Zoladex
# Clarithromycin
# Tranylcypromine
# Phentermine
# Prednisolone
# Tarceva
# Ezetimibe / simvastatin
# Belsomra
# Enbrel
# Flexeril
# Ethinyl estradiol / levonorgestrel
# Prozac
# Clomipramine
# Klonopin
# Ethinyl estradiol / norgestimate
# Zovirax
# Adipex-P
# Vilazodone
# Etonogestrel
# Buspirone
# Phentermine / topiramate
# Micardis HCT
# Dapsone
# TriNessa
# Estarylla
# Venlafaxine
# Aviane
# Geodon
# Tiotropium
# Remicade
# Synthroid
# Minocycline
# Ativan
# Eletriptan
# Levoxyl
# Duloxetine
# Dexbrompheniramine / pseudoephedrine
# Loestrin 24 Fe
# Haloperidol
# Nexplanon
# Robaxin
# Cefdinir
# Ortho Tri-Cyclen Lo
# Desogen
# Hiprex
# Lorazepam
# Loratadine / pseudoephedrine
# Lyrica
# Norco
# Ethinyl estradiol / norelgestromin
# Ambrisentan
# Trulicity
# Duac
# Zyrtec
# Propranolol
# Alli
# Exemestane
# Mirena
# NuvaRing
# Ethinyl estradiol / norethindrone
# Desogestrel / ethinyl estradiol
# Magnesium sulfate / potassium sulfate / sodium sulfate
# Methylphenidate
# Aripiprazole
# Oxycodone
# Isotretinoin
# Finasteride
# Unisom SleepTabs
# Diazepam
# Effexor XR
# Mirtazapine
# Citalopram
# Medroxyprogesterone
# Colchicine
# Trazodone
# Prevacid
# Losartan
# Metronidazole
# Temazepam
# Plan B One-Step
# Suboxone
# Azelastine / fluticasone
# Diazepam Intensol
# Tioconazole
# Drysol
# Levomilnacipran
# Ondansetron
# Contrave
# Botox
# Cobicistat / elvitegravir / emtricitabine / tenofovir alafenamide
# Diclofenac
# Tums Regular Strength
# Anafranil
# Atripla
# Dextromethorphan
# Acetaminophen / hydrocodone
# Invokana
# Promethazine
# Nora-Be
# Methadone
# Bismuth subcitrate potassium / metronidazole / tetracycline
# Hydroxyzine
# Cymbalta
# Implanon
# Tikosyn
# Paroxetine
# Zolpidem
# Olanzapine
# Plan B
# Chantix
# Macrobid
# Adderall XR
# Ciprofloxacin
# Fingolimod
# Sumatriptan
# Pristiq
# Lexapro
# Luvox
# Hydroxyprogesterone
# Viibryd
# Rabeprazole
# Monistat 7
# Movantik
# Bismuth subsalicylate
# Aranesp
# Bisoprolol
# Motofen
# Dextromethorphan / guaifenesin
# Diovan
# Medrol Dosepak
# Zonisamide
# Fludrocortisone
# Maxifed DM
# Reclipsen
# Echinacea
# Dexlansoprazole
# Vanspar
# Cafergot
# Hydrea
# Metoprolol
# Prempro
# Pancrelipase
# SMZ-TMP DS
# Ibandronate
# Glucophage XR
# Atarax
# Vitamin B12
# Synalar Ointment
# Imdur
# Advil Cold and Sinus
# Hydrochlorothiazide / olmesartan
# Lialda
# Emend
# Spectracef
# Doxylamine
# Tegretol
# Exforge
# Zyrtec-D
# Fenofibrate
# Zomig
# Rajani
# Ezetimibe
# Di-Gel
# Acular LS
# Jencycla
# Gilenya
# Lamisil
# Biaxin
# Opium
# Xyzal
# Biaxin XL
# Monistat 3-Day Combination Pack
# Neurontin
# Nucynta ER
# Quasense
# Denosumab
# Orphenadrine
# Microgestin 1 / 20
# Rosuvastatin
# Jublia
# Estradiol / levonorgestrel
# Lyza
# Zeasorb-AF
# Tresiba
# Aplenzin
# Dextromethorphan / quinidine
# Neosporin
# Junel Fe 1.5 / 30
# Rythmol SR
# Equetro
# Azopt
# Sofosbuvir / velpatasvir
# Acetaminophen / pamabrom
# Methotrexate
# Alfuzosin
# Diamox Sequels
# Oracea
# Trilipix
# Parafon Forte DSC
# Famvir
# Naprelan
# Delsym
# Zohydro ER
# Diflucan
# Frova
# DynaCirc CR
# Macrodantin
# Almotriptan
# Metaxalone
# Generess Fe
# Amlodipine / olmesartan
# Zioptan
# Meningococcal conjugate vaccine
# Propafenone
# Multivitamin, prenatal
# Advil
# Loratadine
# Prevalite
# Lidoderm
# Azelastine
# Yohimbine
# Sprycel
# Cyred
# Atrovent Nasal
# Ethinyl estradiol / norgestrel
# Levalbuterol
# Levemir
# Acetaminophen / codeine
# Albendazole
# Opana
# Raltegravir
# Zyclara
# Naphazoline
# Methylnaltrexone
# Acetaminophen / butalbital
# Yuvafem
# Deblitane
# Ocella
# Zegerid
# Entacapone
# X-Viate
# Sitavig
# Nature-Throid
# Ultracet
# Safyral
# Teriparatide
# Requip
# Tegretol XR
# Keflex
# Accolate
# Robaxin-750
# Fiorinal
# Keytruda
# Natesto
# Diphenhydramine
# Azilsartan medoxomil
# Empagliflozin / metformin
# Flecainide
# Guaifenesin / phenylephrine
# Altabax
# Dexamethasone
# Abacavir / dolutegravir / lamivudine
# Evolocumab
# Microgestin Fe 1.5 / 30
# Flonase
# Armour Thyroid
# Gardasil
# Ketoprofen
# Carbidopa / levodopa
# Azo-Standard
# Nuvigil
# Acetaminophen
# Budesonide / formoterol
# Fortesta
# Aspirin / butalbital / caffeine
# Xylocaine Jelly
# Phenazopyridine
# GaviLyte-N
# Dalmane
# Claravis
# Daytrana
# Propulsid
# Histrelin
# Omeprazole / sodium bicarbonate
# Secukinumab
# Dienogest / estradiol
# Amoxil
# Gildess Fe 1.5 / 30
# Loestrin 21 1 / 20
# Tradjenta
# Dupilumab
# Demerol
# Dramamine
# Chlorpromazine
# Tekturna HCT
# Depo-Testosterone
# Prograf
# Red yeast rice
# Sorafenib
# Sominex
# Halofantrine
# Imbruvica
# Ketotifen
# Mebaral
# pHisoHex
# Lovastatin / niacin
# Visine Totality Multi-Symptom Relief
# Uceris
# Vectibix
# Trolamine salicylate
# Phendiet
# Balziva
# Pyrithione zinc
# Patanase
# Umeclidinium
# Corlanor
# Qvar
# Clobazam
# BenzEFoam Ultra
# Chlorcyclizine / phenylephrine
# Coagulation factor ix
# Acetaminophen / caffeine / isometheptene mucate
# Aliskiren / hydrochlorothiazide
# Sulfacetamide sodium
# Habitrol
# Fluoride
# Hydrocodone / pseudoephedrine
# Ziac
# Ritonavir
# Alclometasone
# Caverject
# Triamterene
# Lactic acid
# Felbatol
# Amcinonide
# Tri-Lo-Marzia
# Prostigmin Bromide
# Disopyramide
# Naloxone / pentazocine
# Rowasa
# Rocaltrol
# Follicle stimulating hormone
# Intron A
# Ertaczo
# ConZip
# Buproban
# Naftifine
# Slow Fe
# Sorbitol
# Oxaprozin
# Monurol
# Iophen-C NR
# Tryptophan
# Revatio
# Calci-Chew
# Sterapred DS
# Acetaminophen / caffeine / dihydrocodeine
# Rosiglitazone
# Budeprion XL
# Acnex
# Anacin
# Nimotop
# Sleep Aid
# Anaprox
# Flagyl IV
# VisRx Dose Pack
# Cardizem
# Dermatop
# Capzasin-P
# D.H.E. 45
# Acetaminophen / dextromethorphan / pseudoephedrine
# Silver
# Topicort
# Axid
# OsmoPrep
# Colyte
# Actifed
# Berinert
# Exparel
# Prosom
# Acetaminophen / chlorpheniramine / phenylephrine
# Cyclafem 1 / 35
# Generlac
# Tazarotene
# Carboplatin
# Vantin
# Bronkaid
# Prezcobix
# Propecia
# Demadex
# Mevacor
# Hydroxocobalamin
# Brimonidine / timolol
# Erythrocin
# Aldactazide
# Valturna
# Doripenem
# Atelvia
# Nitrolingual Pumpspray
# Adcirca
# Targretin
# Coricidin HBP Cold & Flu
# Relenza
# Lariam
# Palbociclib
# Ethmozine
# Menthol / zinc oxide
# Stimate
# Motrin Infant Drops
# NuOx
# Feen-A-Mint
# Reclast
# Moderiba
# Loestrin Fe 1 / 20
# Cosopt PF
# Amitriptyline / chlordiazepoxide
# Ritalin LA
# Pulmozyme
# Promethazine DM
# NovoLog FlexPen
# Loxapine
# Azelex
# Travoprost
# Nystop
# Zolpimist
# Prialt
# Zarontin
# Undecylenic acid
# CoQ10
# Fosinopril
# Insulin lispro
# Ginger
# Cenestin
# Unasyn
# Stromectol
# Suprenza
# Incivek
# Flovent
# Zemaira
# Butabarbital
# Anakinra
# Dasetta 7 / 7 / 7
# Coricidin HBP Cough & Cold
# Ethotoin
# Menopur
# Danocrine
# Prinivil
# Camphor / menthol
# Cedax
# Esgic-Plus
# Q-Tapp DM
# Ansaid
# Allegra Allergy
# Ephedrine
# Sucroferric oxyhydroxide
# Paclitaxel
# Protonix IV
# Navane
# FluMist
# Excedrin Quick Tab
# B & O Supprettes
# AbobotulinumtoxinA
# Spiriva Respimat
# Asacol HD
# Capecitabine
# Silver nitrate
# RadiaPlexRx
# Calcium acetate
# Doxidan Tablet
# Kaletra
# Noritate
# Brivaracetam
# Dextrostat
# Penicillin g benzathine
# Prodrin
# Acetaminophen / dextromethorphan / guaifenesin / pseudoephedrine
# Dorzolamide / timolol
# KneeRelief
# FiberCon
# Ponatinib
# Norpace CR
# Influenza virus vaccine, inactivated
# Serostim
# Cefepime
# Rho (d) immune globulin
# Toujeo Solostar
# Cosopt
# Tiagabine
# Novantrone
# Mucomyst-10
# Lovaza
# Abstral
# Ivacaftor
# Trimipramine
# Disalcid
# Aluminum hydroxide / magnesium hydroxide / simethicone
# Xeomin
# Vitafol Ultra
# Sodium ferric gluconate complex
# Kionex
# Metadate ER
# Guaifenesin / hydrocodone
# Ferrous fumarate / iron polysaccharide
# TheraTears
# Limbitrol DS
# Biafine
# Renvela
# Colace
# Pemoline
# Aristocort
# Radium 223 dichloride
# Zovia 1 / 35
# Nimodipine
# Migergot
# Norepinephrine
# Tylenol Cold
# Eldepryl
# Lemtrada
# Eovist
# Tranxene SD
# Rosac
# Coal tar
# Vicks Sinex 12-Hour Decongestant Nasal Spray
# MG217 Medicated Tar
# Moxeza
# Didrex
# Nplate
# Prolensa
# Ribasphere
# Exubera
# Vicodin HP
# Tinzaparin
# Lomedia 24 Fe
# Evista
# Dasabuvir / ombitasvir / paritaprevir / ritonavir
# Periogard
# Tolak
# Asthmanefrin
# Gamunex
# Limbrel
# Nizatidine
# Nafcillin
# Venofer
# Magnesium salicylate

# %%
pd.set_option("display.max_rows", None)
frequence = complete_dataset['drugName'].value_counts()
print(frequence)
# Out:
# Levonorgestrel                                                                                      1265
# Etonogestrel                                                                                        1081
# Ethinyl estradiol / norethindrone                                                                    869
# Nexplanon                                                                                            736
# Ethinyl estradiol / norgestimate                                                                     649
# Ethinyl estradiol / levonorgestrel                                                                   591
# Phentermine                                                                                          539
# Sertraline                                                                                           506
# Escitalopram                                                                                         452
# Mirena                                                                                               431
# Implanon                                                                                             404
# Gabapentin                                                                                           367
# Miconazole                                                                                           343
# Bupropion                                                                                            343
# Venlafaxine                                                                                          320
# Duloxetine                                                                                           320
# Tramadol                                                                                             316
# Clonazepam                                                                                           315
# Citalopram                                                                                           312
# Medroxyprogesterone                                                                                  302
# Lexapro                                                                                              298
# Bupropion / naltrexone                                                                               296
# Varenicline                                                                                          295
# Contrave                                                                                             295
# Metronidazole                                                                                        285
# Drospirenone / ethinyl estradiol                                                                     284
# Zoloft                                                                                               281
# Cymbalta                                                                                             278
# Tioconazole                                                                                          274
# Depo-Provera                                                                                         273
# Liraglutide                                                                                          265
# Skyla                                                                                                252
# Fluoxetine                                                                                           245
# Quetiapine                                                                                           243
# Lo Loestrin Fe                                                                                       234
# Alprazolam                                                                                           226
# Chantix                                                                                              225
# Amitriptyline                                                                                        225
# Doxycycline                                                                                          215
# Desvenlafaxine                                                                                       213
# Trazodone                                                                                            211
# Suprep Bowel Prep Kit                                                                                209
# Paroxetine                                                                                           207
# NuvaRing                                                                                             204
# Bisacodyl                                                                                            202
# Lorcaserin                                                                                           200
# Ethinyl estradiol / etonogestrel                                                                     198
# Sprintec                                                                                             197
# Magnesium sulfate / potassium sulfate / sodium sulfate                                               196
# Pregabalin                                                                                           195
# Copper                                                                                               193
# Belviq                                                                                               192
# Lamotrigine                                                                                          191
# Plan B                                                                                               189
# Acetaminophen / hydrocodone                                                                          188
# Pristiq                                                                                              182
# Topiramate                                                                                           182
# Mirtazapine                                                                                          178
# Azithromycin                                                                                         178
# Sulfamethoxazole / trimethoprim                                                                      176
# Vortioxetine                                                                                         175
# Oxycodone                                                                                            171
# Celexa                                                                                               171
# Isotretinoin                                                                                         168
# Buprenorphine / naloxone                                                                             167
# Vyvanse                                                                                              167
# Nitrofurantoin                                                                                       165
# Aripiprazole                                                                                         164
# Desogestrel / ethinyl estradiol                                                                      164
# Lorazepam                                                                                            164
# Loestrin 24 Fe                                                                                       163
# Lisdexamfetamine                                                                                     162
# Lyrica                                                                                               162
# Propranolol                                                                                          161
# Acetaminophen / oxycodone                                                                            154
# Buspirone                                                                                            152
# Prozac                                                                                               152
# Adapalene / benzoyl peroxide                                                                         150
# Xanax                                                                                                149
# Abilify                                                                                              147
# Zolpidem                                                                                             147
# Hydroxyzine                                                                                          147
# Methylphenidate                                                                                      144
# Paxil                                                                                                143
# ParaGard                                                                                             140
# Yaz                                                                                                  138
# Viibryd                                                                                              137
# Phentermine / topiramate                                                                             135
# Ethinyl estradiol / norelgestromin                                                                   135
# Diclofenac                                                                                           135
# Plan B One-Step                                                                                      128
# Amphetamine / dextroamphetamine                                                                      127
# Vilazodone                                                                                           127
# Microgestin Fe 1 / 20                                                                                126
# Clindamycin                                                                                          125
# Norethindrone                                                                                        125
# Effexor XR                                                                                           123
# Saxenda                                                                                              123
# Victoza                                                                                              122
# Klonopin                                                                                             121
# Suboxone                                                                                             120
# Lurasidone                                                                                           120
# Ciprofloxacin                                                                                        117
# Wellbutrin                                                                                           116
# Adipex-P                                                                                             115
# Methadone                                                                                            114
# Aluminum chloride hexahydrate                                                                        113
# Minocycline                                                                                          113
# Dulcolax                                                                                             112
# Testosterone                                                                                         112
# Accutane                                                                                             111
# Qsymia                                                                                               110
# Tri-Sprintec                                                                                         109
# Topamax                                                                                              108
# Lamictal                                                                                             106
# Tadalafil                                                                                            103
# Prednisone                                                                                           102
# Amoxicillin / clavulanate                                                                            102
# Latuda                                                                                               101
# Clarithromycin                                                                                       101
# Cyclobenzaprine                                                                                       99
# Lisinopril                                                                                            98
# Levofloxacin                                                                                          96
# Aviane                                                                                                95
# Diazepam                                                                                              95
# Ambien                                                                                                95
# Seroquel                                                                                              94
# Benzoyl peroxide / clindamycin                                                                        94
# Linzess                                                                                               93
# TriNessa                                                                                              93
# Linaclotide                                                                                           93
# Fentanyl                                                                                              92
# Naproxen                                                                                              91
# Olanzapine                                                                                            90
# Effexor                                                                                               90
# Trintellix                                                                                            90
# Epiduo                                                                                                89
# Cialis                                                                                                89
# Adalimumab                                                                                            87
# Levothyroxine                                                                                         87
# Risperidone                                                                                           86
# Nortriptyline                                                                                         86
# Hydromorphone                                                                                         85
# Atomoxetine                                                                                           85
# Tretinoin                                                                                             83
# Strattera                                                                                             82
# BuSpar                                                                                                82
# Clonidine                                                                                             82
# Ativan                                                                                                81
# Humira                                                                                                81
# Polyethylene glycol 3350 with electrolytes                                                            80
# Levaquin                                                                                              80
# Macrobid                                                                                              79
# Milnacipran                                                                                           78
# Ledipasvir / sofosbuvir                                                                               77
# Ondansetron                                                                                           77
# Lutera                                                                                                77
# Metformin                                                                                             76
# Belsomra                                                                                              76
# Spironolactone                                                                                        76
# Buprenorphine                                                                                         76
# Metoprolol                                                                                            75
# Sumatriptan                                                                                           74
# Meloxicam                                                                                             73
# Adderall                                                                                              72
# Tapentadol                                                                                            72
# Ortho Evra                                                                                            72
# Suvorexant                                                                                            72
# Ziprasidone                                                                                           71
# Montelukast                                                                                           71
# Benzonatate                                                                                           71
# Amlodipine                                                                                            71
# Concerta                                                                                              70
# Harvoni                                                                                               70
# Modafinil                                                                                             70
# Carbamazepine                                                                                         69
# Dilaudid                                                                                              68
# Dulaglutide                                                                                           68
# Ortho Tri-Cyclen Lo                                                                                   68
# Propofol                                                                                              68
# Trulicity                                                                                             68
# Savella                                                                                               67
# Oseltamivir                                                                                           67
# Lithium                                                                                               67
# Apri                                                                                                  66
# Estradiol                                                                                             66
# Armodafinil                                                                                           66
# Divalproex sodium                                                                                     66
# Junel Fe 1 / 20                                                                                       66
# OxyContin                                                                                             65
# Ropinirole                                                                                            65
# Metoclopramide                                                                                        65
# Sildenafil                                                                                            63
# Liletta                                                                                               63
# Ketorolac                                                                                             63
# Drysol                                                                                                62
# Adapalene                                                                                             62
# Yasmin                                                                                                61
# Fluconazole                                                                                           61
# Bactrim                                                                                               61
# Seasonique                                                                                            61
# Tamsulosin                                                                                            61
# Valacyclovir                                                                                          60
# Baclofen                                                                                              60
# Imiquimod                                                                                             60
# Oxybutynin                                                                                            59
# Morphine                                                                                              59
# Geodon                                                                                                59
# Wellbutrin XL                                                                                         58
# Augmentin                                                                                             58
# Ultram                                                                                                57
# Levetiracetam                                                                                         57
# Mesalamine                                                                                            57
# Docosanol                                                                                             56
# Tamiflu                                                                                               56
# Nuvigil                                                                                               56
# Kyleena                                                                                               55
# Asenapine                                                                                             55
# Losartan                                                                                              55
# Mononessa                                                                                             54
# Naltrexone                                                                                            53
# Rizatriptan                                                                                           53
# MoviPrep                                                                                              53
# Exenatide                                                                                             53
# OnabotulinumtoxinA                                                                                    52
# Terbinafine                                                                                           52
# Oxymorphone                                                                                           52
# Etanercept                                                                                            51
# Methylprednisolone                                                                                    51
# Gildess Fe 1 / 20                                                                                     51
# Canagliflozin                                                                                         50
# Cipro                                                                                                 50
# Ethinyl estradiol / norgestrel                                                                        50
# Norco                                                                                                 50
# Doxepin                                                                                               50
# Apremilast                                                                                            50
# Temazepam                                                                                             50
# Acetaminophen / butalbital / caffeine                                                                 49
# Orlistat                                                                                              49
# Valtrex                                                                                               49
# Dextromethorphan                                                                                      49
# Thyroid desiccated                                                                                    49
# Promethazine                                                                                          49
# Botox                                                                                                 49
# Cephalexin                                                                                            48
# Invokana                                                                                              48
# Levora                                                                                                48
# Saphris                                                                                               48
# Enbrel                                                                                                48
# Otezla                                                                                                48
# Hypercare                                                                                             48
# Eszopiclone                                                                                           48
# Abreva                                                                                                47
# Keppra                                                                                                47
# Tizanidine                                                                                            47
# Dapsone                                                                                               47
# Xulane                                                                                                46
# Minastrin 24 Fe                                                                                       46
# Magnesium citrate                                                                                     45
# Sodium hyaluronate                                                                                    45
# Leuprolide                                                                                            45
# Lunesta                                                                                               45
# Viagra                                                                                                45
# Zyprexa                                                                                               45
# Oxcarbazepine                                                                                         44
# Methocarbamol                                                                                         44
# Percocet                                                                                              44
# Guanfacine                                                                                            44
# Orsythia                                                                                              43
# Gianvi                                                                                                43
# Depakote                                                                                              43
# Mucinex D                                                                                             43
# Differin                                                                                              43
# Carisoprodol                                                                                          43
# Valium                                                                                                42
# Ortho Tri-Cyclen                                                                                      42
# Lubiprostone                                                                                          42
# Nucynta                                                                                               42
# Celecoxib                                                                                             42
# Remeron                                                                                               42
# Hydroxychloroquine                                                                                    42
# Methotrexate                                                                                          41
# Levocetirizine                                                                                        41
# Zofran                                                                                                41
# Cefdinir                                                                                              41
# Guaifenesin                                                                                           41
# Duac                                                                                                  40
# Neurontin                                                                                             40
# Acyclovir                                                                                             40
# Moxifloxacin                                                                                          40
# Butrans                                                                                               40
# Reglan                                                                                                40
# Drospirenone / ethinyl estradiol / levomefolate calcium                                               39
# Estarylla                                                                                             39
# Pramipexole                                                                                           39
# Elavil                                                                                                39
# Singulair                                                                                             39
# Flomax                                                                                                39
# Cetirizine                                                                                            39
# Aczone                                                                                                39
# Avelox                                                                                                39
# Cyproheptadine                                                                                        38
# Chateal                                                                                               38
# Naloxegol                                                                                             38
# Amitiza                                                                                               38
# Atenolol                                                                                              37
# Seroquel XR                                                                                           37
# Guaifenesin / pseudoephedrine                                                                         37
# Diphenhydramine                                                                                       36
# Fetzima                                                                                               36
# Celebrex                                                                                              36
# Xyzal                                                                                                 36
# Bydureon                                                                                              36
# Bystolic                                                                                              36
# Flagyl                                                                                                36
# Bactrim DS                                                                                            35
# Risperdal                                                                                             35
# Imitrex                                                                                               35
# Dexlansoprazole                                                                                       35
# Anastrozole                                                                                           35
# Indomethacin                                                                                          35
# Adderall XR                                                                                           35
# LoSeasonique                                                                                          35
# Vardenafil                                                                                            35
# Beyaz                                                                                                 35
# Fluticasone                                                                                           34
# Lidocaine                                                                                             34
# Eluxadoline                                                                                           34
# Vistaril                                                                                              34
# Prazosin                                                                                              34
# Fluvoxamine                                                                                           34
# Viberzi                                                                                               34
# Acamprosate                                                                                           34
# Ivermectin                                                                                            34
# Dicyclomine                                                                                           33
# Voltaren Gel                                                                                          33
# Lortab                                                                                                33
# Tri-Previfem                                                                                          33
# Zyrtec                                                                                                33
# Ranitidine                                                                                            33
# Movantik                                                                                              33
# Polyethylene glycol 3350                                                                              33
# Alesse                                                                                                33
# Phendimetrazine                                                                                       32
# Flexeril                                                                                              32
# Clindamycin / tretinoin                                                                               32
# Eletriptan                                                                                            32
# Levomilnacipran                                                                                       32
# Dextroamphetamine                                                                                     32
# Provigil                                                                                              32
# Amoxicillin                                                                                           32
# Ocella                                                                                                32
# Toradol                                                                                               32
# Aubra                                                                                                 32
# Paliperidone                                                                                          32
# Fioricet                                                                                              32
# Clomipramine                                                                                          31
# Campral                                                                                               31
# Mirabegron                                                                                            31
# Euflexxa                                                                                              31
# Requip                                                                                                30
# Dexilant                                                                                              30
# Citric acid / magnesium oxide / sodium picosulfate                                                    30
# Budesonide / formoterol                                                                               30
# Nebivolol                                                                                             30
# Infliximab                                                                                            30
# Doxylamine                                                                                            30
# Triamcinolone                                                                                         30
# Blisovi 24 Fe                                                                                         30
# Silenor                                                                                               30
# Claravis                                                                                              30
# Mometasone                                                                                            30
# Omeprazole                                                                                            30
# Vivitrol                                                                                              30
# Meclizine                                                                                             30
# Sronyx                                                                                                30
# Portia                                                                                                29
# Nicotine                                                                                              29
# Monistat 3-Day Combination Pack                                                                       29
# Prepopik                                                                                              29
# Monistat 7-Day Combination Pack                                                                       29
# Pantoprazole                                                                                          29
# Copaxone                                                                                              29
# Vicodin                                                                                               29
# Tylenol with Codeine #3                                                                               29
# Stelara                                                                                               29
# Camrese                                                                                               28
# Solifenacin                                                                                           28
# Hydrochlorothiazide                                                                                   28
# Melatonin                                                                                             28
# Crestor                                                                                               28
# Carvedilol                                                                                            28
# Brimonidine                                                                                           28
# Acetaminophen / codeine                                                                               28
# Jublia                                                                                                28
# Scopolamine                                                                                           28
# Hyaluronan                                                                                            28
# Glatiramer                                                                                            27
# Rosuvastatin                                                                                          27
# Verapamil                                                                                             27
# MiraLax                                                                                               27
# Atorvastatin                                                                                          27
# Ustekinumab                                                                                           27
# Levitra                                                                                               27
# Diethylpropion                                                                                        27
# VESIcare                                                                                              27
# Ortho Micronor                                                                                        27
# Monistat 7                                                                                            26
# Silodosin                                                                                             26
# Phillips' Milk of Magnesia                                                                            26
# Chlordiazepoxide                                                                                      26
# Naproxen / sumatriptan                                                                                26
# Phenazopyridine                                                                                       26
# Acetazolamide                                                                                         26
# Remicade                                                                                              26
# Cryselle                                                                                              26
# Jolessa                                                                                               26
# Treximet                                                                                              26
# Acetaminophen / aspirin / caffeine                                                                    26
# Vimpat                                                                                                26
# Fluorouracil                                                                                          26
# Olmesartan                                                                                            25
# Synthroid                                                                                             25
# Armour Thyroid                                                                                        25
# Plaquenil                                                                                             25
# Myrbetriq                                                                                             25
# Mobic                                                                                                 25
# Diltiazem                                                                                             25
# Prochlorperazine                                                                                      25
# Tegretol                                                                                              25
# Xarelto                                                                                               25
# Clobetasol                                                                                            25
# Intuniv                                                                                               25
# Zolmitriptan                                                                                          25
# Reclipsen                                                                                             25
# Benicar                                                                                               25
# Dexmethylphenidate                                                                                    24
# Rivaroxaban                                                                                           24
# Provera                                                                                               24
# Xiidra                                                                                                24
# Efinaconazole                                                                                         24
# Solodyn                                                                                               24
# Delsym                                                                                                24
# Voltaren                                                                                              24
# Orthovisc                                                                                             24
# Tussionex Pennkinetic                                                                                 24
# Wellbutrin SR                                                                                         24
# Generess Fe                                                                                           24
# Oxymetazoline                                                                                         24
# Brexpiprazole                                                                                         24
# Flecainide                                                                                            24
# Soma                                                                                                  24
# Zithromax                                                                                             24
# Efavirenz / emtricitabine / tenofovir                                                                 23
# Tranexamic acid                                                                                       23
# Hysingla ER                                                                                           23
# Librium                                                                                               23
# ...
# Cervidil                                                                                               1
# Doribax                                                                                                1
# Condylox                                                                                               1
# DynaCirc CR                                                                                            1
# GenTeal                                                                                                1
# Simponi Aria                                                                                           1
# Premphase                                                                                              1
# Dexamethasone Intensol                                                                                 1
# Aspirin / meprobamate                                                                                  1
# Dronedarone                                                                                            1
# Aveed                                                                                                  1
# Rebif Rebidose                                                                                         1
# Egrifta                                                                                                1
# Remeron SolTab                                                                                         1
# Olodaterol                                                                                             1
# Ubiquinone                                                                                             1
# Robitussin Cough + Chest Congestion DM                                                                 1
# Benzoic acid / salicylic acid                                                                          1
# Coartem                                                                                                1
# Zovia 1 / 50                                                                                           1
# Gabitril                                                                                               1
# Combivir                                                                                               1
# Acuvail                                                                                                1
# Ex-Lax Regular Strength Pills                                                                          1
# Enfuvirtide                                                                                            1
# Elestrin                                                                                               1
# Gentian violet                                                                                         1
# Mycophenolic acid                                                                                      1
# Prevalite                                                                                              1
# Excedrin Back & Body                                                                                   1
# Clear Eyes Contact Lens Multi-Action Relief                                                            1
# Ultram ODT                                                                                             1
# Iron sucrose                                                                                           1
# Supprelin LA                                                                                           1
# Meningococcal conjugate vaccine                                                                        1
# Lesinurad                                                                                              1
# Selexipag                                                                                              1
# Caziant                                                                                                1
# Gold sodium thiomalate                                                                                 1
# Nuvessa                                                                                                1
# Rezira                                                                                                 1
# Derma-Smoothe / FS (Scalp)                                                                             1
# Afinitor                                                                                               1
# Premsyn PMS                                                                                            1
# Sine-Off Maximum Strength                                                                              1
# Selsun Blue                                                                                            1
# Vienva                                                                                                 1
# Hydroxyamphetamine / tropicamide                                                                       1
# Accolate                                                                                               1
# Megace ES                                                                                              1
# Symax Duotab                                                                                           1
# Cyklokapron                                                                                            1
# Zebeta                                                                                                 1
# Anucort-HC                                                                                             1
# Ceftibuten                                                                                             1
# Primatene                                                                                              1
# Addyi                                                                                                  1
# Estraderm                                                                                              1
# Avonex Pen                                                                                             1
# Luvox CR                                                                                               1
# Cinacalcet                                                                                             1
# Capsaicin / menthol / methyl salicylate                                                                1
# Methyldopa                                                                                             1
# Odefsey                                                                                                1
# Florinef Acetate                                                                                       1
# ActoPlus Met                                                                                           1
# Axid AR                                                                                                1
# Lactase                                                                                                1
# ZzzQuil                                                                                                1
# Tigan                                                                                                  1
# Advicor                                                                                                1
# Plegridy                                                                                               1
# Sterapred                                                                                              1
# S-adenosylmethionine                                                                                   1
# Humulin N                                                                                              1
# Nyamyc                                                                                                 1
# Rydapt                                                                                                 1
# Pegloticase                                                                                            1
# Fluoroplex                                                                                             1
# Q-Dryl                                                                                                 1
# Eletone                                                                                                1
# Edecrin                                                                                                1
# Racepinephrine                                                                                         1
# Oraqix                                                                                                 1
# TriLyte                                                                                                1
# Ritalin-SR                                                                                             1
# Trilisate                                                                                              1
# Balsam peru / castor oil / trypsin                                                                     1
# Adalat CC                                                                                              1
# Succinylcholine                                                                                        1
# Calamine                                                                                               1
# Nembutal Sodium                                                                                        1
# Chlorpheniramine / methscopolamine / pseudoephedrine                                                   1
# Ginseng                                                                                                1
# Glyburide / metformin                                                                                  1
# Hetlioz                                                                                                1
# Ornex                                                                                                  1
# Bayer Aspirin                                                                                          1
# Zirgan                                                                                                 1
# Ferrous gluconate                                                                                      1
# Rogaine Men's Extra Strength                                                                           1
# Opsumit                                                                                                1
# Stelazine                                                                                              1
# Sinequan                                                                                               1
# Tylenol Allergy Multi-Symptom Nighttime                                                                1
# Vitamin D3                                                                                             1
# Perindopril                                                                                            1
# Neo-Synephrine Nasal                                                                                   1
# Saccharomyces boulardii lyo                                                                            1
# Pegaptanib                                                                                             1
# Buprenex                                                                                               1
# Cefditoren                                                                                             1
# Vectical                                                                                               1
# Menotropins                                                                                            1
# Sotret                                                                                                 1
# Macitentan                                                                                             1
# Lacrisert                                                                                              1
# Empagliflozin / metformin                                                                              1
# Dobutamine                                                                                             1
# Alprazolam Intensol                                                                                    1
# Bacitracin / neomycin / polymyxin b                                                                    1
# Trusopt                                                                                                1
# FreshKote                                                                                              1
# Decadron                                                                                               1
# Betapace                                                                                               1
# Pacerone                                                                                               1
# Duofilm                                                                                                1
# Pyrantel                                                                                               1
# Peridex                                                                                                1
# Salicylic acid / sulfur                                                                                1
# Halfan                                                                                                 1
# Aerobid                                                                                                1
# Prometrium                                                                                             1
# Propulsid                                                                                              1
# Dapagliflozin / metformin                                                                              1
# Tribenzor                                                                                              1
# Urso                                                                                                   1
# Pramlintide                                                                                            1
# Vospire ER                                                                                             1
# Calcitonin                                                                                             1
# Ceritinib                                                                                              1
# Xylocaine Jelly                                                                                        1
# Hylenex                                                                                                1
# Miacalcin Nasal                                                                                        1
# Xenaderm                                                                                               1
# Rifabutin                                                                                              1
# Bismuth subgallate                                                                                     1
# Codimal DM                                                                                             1
# Low-Ogestrel-21                                                                                        1
# Crizotinib                                                                                             1
# Pletal                                                                                                 1
# Magnesium salicylate                                                                                   1
# Name: drugName, dtype: int64

# %% [markdown]
# -Removed brand name drugs from dataset so that model did not classify brand/generic as two separate medications (ex. Lexapro/Escitalopram or Chantix/Varenicline)

# %%
base_dir = os.path.join(data_dir,'drugs')
if not os.path.exists(base_dir):
    os.makedirs(base_dir)

drug_names = ["Levonorgestrel",
              "Etonogestrel",
              "Ethinyl estradiol / norethindrone",
              "Nexplanon",
              "Ethinyl estradiol / norgestimate",
              "Ethinyl estradiol / levonorgestrel",
              "Phentermine",
              "Sertraline",
              "Escitalopram",
              "Mirena",
              "Implanon",
              "Gabapentin",
              "Miconazole",
              "Bupropion",
              "Venlafaxine",
              "Duloxetine",
              "Tramadol",
              "Clonazepam",
              "Citalopram",
              "Medroxyprogesterone",
              "Bupropion / naltrexone",
              "Varenicline",
              "Metronidazole",
              "Drospirenone / ethinyl estradiol",
              "Tioconazole",
              "Depo-Provera",
              "Liraglutide",
              "Skyla",
              "Fluoxetine",
              "Quetiapine",
              "Lo Loestrin Fe",
              "Alprazolam",
              "Chantix",
              "Amitriptyline",
              "Doxycycline",
              "Desvenlafaxine",
              "Trazodone",
              "Suprep Bowel Prep Kit",
              "Paroxetine",
              "NuvaRing",
              "Bisacodyl",
              "Lorcaserin"]
drug_directories = []

for drug_name in drug_names:
    current_drug_dir = os.path.join(data_dir,'drugs',drug_name)
    print(current_drug_dir)
    drug_directories.append(current_drug_dir)
    if not os.path.exists(current_drug_dir):
        os.makedirs(current_drug_dir)
# Out:
# /tf/data/drugs/Levonorgestrel
# /tf/data/drugs/Etonogestrel
# /tf/data/drugs/Ethinyl estradiol / norethindrone
# /tf/data/drugs/Nexplanon
# /tf/data/drugs/Ethinyl estradiol / norgestimate
# /tf/data/drugs/Ethinyl estradiol / levonorgestrel
# /tf/data/drugs/Phentermine
# /tf/data/drugs/Sertraline
# /tf/data/drugs/Escitalopram
# /tf/data/drugs/Mirena
# /tf/data/drugs/Implanon
# /tf/data/drugs/Gabapentin
# /tf/data/drugs/Miconazole
# /tf/data/drugs/Bupropion
# /tf/data/drugs/Venlafaxine
# /tf/data/drugs/Duloxetine
# /tf/data/drugs/Tramadol
# /tf/data/drugs/Clonazepam
# /tf/data/drugs/Citalopram
# /tf/data/drugs/Medroxyprogesterone
# /tf/data/drugs/Bupropion / naltrexone
# /tf/data/drugs/Varenicline
# /tf/data/drugs/Metronidazole
# /tf/data/drugs/Drospirenone / ethinyl estradiol
# /tf/data/drugs/Tioconazole
# /tf/data/drugs/Depo-Provera
# /tf/data/drugs/Liraglutide
# /tf/data/drugs/Skyla
# /tf/data/drugs/Fluoxetine
# /tf/data/drugs/Quetiapine
# /tf/data/drugs/Lo Loestrin Fe
# /tf/data/drugs/Alprazolam
# /tf/data/drugs/Chantix
# /tf/data/drugs/Amitriptyline
# /tf/data/drugs/Doxycycline
# /tf/data/drugs/Desvenlafaxine
# /tf/data/drugs/Trazodone
# /tf/data/drugs/Suprep Bowel Prep Kit
# /tf/data/drugs/Paroxetine
# /tf/data/drugs/NuvaRing
# /tf/data/drugs/Bisacodyl
# /tf/data/drugs/Lorcaserin

# %%
data = np.array(["Levonorgestrel",
                 "Etonogestrel",
                 "Ethinyl estradiol / norethindrone",
                 "Nexplanon",
                 "Ethinyl estradiol / norgestimate",
                 "Ethinyl estradiol / levonorgestrel",
                 "Phentermine",
                 "Sertraline",
                 "Escitalopram",
                 "Mirena",
                 "Implanon",
                 "Gabapentin",
                 "Miconazole",
                 "Bupropion",
                 "Venlafaxine",
                 "Duloxetine",
                 "Tramadol",
                 "Clonazepam",
                 "Citalopram",
                 "Medroxyprogesterone",
                 "Bupropion / naltrexone",
                 "Varenicline",
                 "Metronidazole",
                 "Drospirenone / ethinyl estradiol",
                 "Tioconazole",
                 "Depo-Provera",
                 "Liraglutide",
                 "Skyla",
                 "Fluoxetine",
                 "Quetiapine",
                 "Lo Loestrin Fe",
                 "Alprazolam", 
                 "Chantix", 
                 "Amitriptyline",
                 "Doxycycline",
                 "Desvenlafaxine",
                 "Trazodone",
                 "Suprep Bowel Prep Kit",
                 "Paroxetine",
                 "NuvaRing",
                 "Bisacodyl",
                 "Lorcaserin"])
s = pd.Series(data)

# %%
print(s[:3])
# Out:
# 0                       Levonorgestrel
# 1                         Etonogestrel
# 2    Ethinyl estradiol / norethindrone
# dtype: object

# %%
print(s[-3:])
# Out:
# 39      NuvaRing
# 40     Bisacodyl
# 41    Lorcaserin
# dtype: object

# %%
complete_dataset.head()
# Out:
#    patient_id       drugName                 condition  \
# 0      184648         Efudex      basal cell carcinoma
# 1       25268  Flector Patch                      pain
# 2      172019        Amitiza  irritable bowel syndrome
# 3      196063        Stendra      erectile dysfunction
# 4      225264      Bupropion                depression
#
#                                               review  rating  \
# 0  "I have BCC on my upper arm and SCC on upper l...     1.0
# 1  "I tore my shoulder labrum and the pain can be...     8.0
# 2             "Amitiza is the best if you have ibs!"    10.0
# 3  "Viagra works in a strong, crude way with side...    10.0
# 4  "I really wanted Wellbutrin to work. I was giv...     3.0
#
#                 date  usefulCount  review_length  \
# 0    August 30, 2016           16             36
# 1       May 29, 2014           40             45
# 2      July 13, 2016            9              8
# 3  November 10, 2014           82            141
# 4    October 4, 2015           15             62
#
#                                              encoded
# 0  [-0.0633561835, 0.0115883639, -0.0027463636, 0...
# 1  [-0.083280459, 0.0182377025, 0.0619471855, 0.0...
# 2  [-0.0300639421, -0.0081300493, 0.0343461707, 0...
# 3  [-0.0037669495, -0.0845683292, 0.0196341239, 0...
# 4  [-0.0633124188, 0.0167291258, 0.0707527027, 0....

# %%
drug_datasets = []
for drug_name in drug_names:

    filtered_df = complete_dataset[complete_dataset['drugName'] == drug_name]
    drug_datasets.append(filtered_df)

# %%
drug_datasets[0].head()

# %%
drug_datasets[41].head()

# %%
print(drug_names[41])
print(drug_directories[41])

# %%
drug_names
drug_directories
drug_datasets

for i in range(len(drug_names)):
    review_counter = 0
    for text in drug_datasets[i]['review']:
        with open(os.path.join(drug_directories[i],str(review_counter)+'.txt'), 'w') as f:
            f.write(text)
        review_counter+=1

# %% [markdown]
# # Loading data set for training
#
# https://www.tensorflow.org/tutorials/load_data/text

# %%
batch_size = 32
seed = 42

raw_train_ds = tf.keras.utils.text_dataset_from_directory(
    pathlib.Path(base_dir),
    batch_size=batch_size,
    validation_split=0.2,
    subset='training',
    seed=seed)

# %%
for text_batch, label_batch in raw_train_ds.take(1):
    for i in range(10):
        print("Patient Review: ", text_batch.numpy()[i])
        print("Label:", label_batch.numpy()[i])

# %%
for i, label in enumerate(raw_train_ds.class_names):
    print("Label", i, "corresponds to", label)

# %%
# Create a validation set.

raw_val_ds = tf.keras.utils.text_dataset_from_directory(
    pathlib.Path(base_dir),
    batch_size=batch_size,
    validation_split=0.2,
    subset='validation',
    seed=seed)

# %%
# Prepare dataset for training

def custom_standardization(input_data):
  lowercase = tf.strings.lower(input_data)
  stripped_html = tf.strings.regex_replace(lowercase, '<br />', ' ')
  return tf.strings.regex_replace(stripped_html,
                                  '[%s]' % re.escape(string.punctuation),
                                  '')

# %%
max_features = 10000
sequence_length = 250

vectorize_layer = layers.TextVectorization(
    standardize=custom_standardization,
    max_tokens=max_features,
    output_mode='int',
    output_sequence_length=sequence_length)

# %%
train_text = raw_train_ds.map(lambda x, y: x)
vectorize_layer.adapt(train_text)

# %%
def vectorize_text(text, label):
  text = tf.expand_dims(text, -1)
  return vectorize_layer(text), label

# %%
text_batch, label_batch = next(iter(raw_train_ds))
first_review, first_label = text_batch[0], label_batch[0]
print("Review", first_review)
print("Label", raw_train_ds.class_names[first_label])
print("Vectorized review", vectorize_text(first_review, first_label))

# %%
print("1287 ---> ",vectorize_layer.get_vocabulary()[1287])
print(" 313 ---> ",vectorize_layer.get_vocabulary()[313])
print('Vocabulary size: {}'.format(len(vectorize_layer.get_vocabulary())))

# %%
#Dataset does not contain test so I'm omitting test_ds = raw_test_ds.map(vectorize_text)

train_ds = raw_train_ds.map(vectorize_text)
val_ds = raw_val_ds.map(vectorize_text)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Create the model

# %%
embedding_dim = 16

# %%
model = tf.keras.Sequential([
  layers.Embedding(max_features + 1, embedding_dim),
  layers.Dropout(0.2),
  layers.GlobalAveragePooling1D(),
  layers.Dropout(0.2),
  layers.Dense(len(drug_names), activation='softmax')])

# %%
model.summary()

# %% [markdown]
# # Train the model

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              optimizer='nadam',
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
epochs = 400
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs)

# %%
loss, accuracy = model.evaluate(train_ds)

print("Loss: ", loss)
print("Accuracy: ", accuracy)

# %%
loss, accuracy = model.evaluate(val_ds)

print("Loss: ", loss)
print("Accuracy: ", accuracy)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()

# %% [markdown]
# # Export the model

# %%
export_model = tf.keras.Sequential([
  vectorize_layer,
  model,
  layers.Activation('softmax')
])

export_model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    optimizer='nadam',
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()]
)

# %%
loss, accuracy = export_model.evaluate(raw_train_ds)
print(accuracy)

# %% [markdown]
# # Inference on new data

# %%
examples = [
  "This medication relieved constipation.",
  "This medication helped me quit smoking.",
  "This medication helped me lose weight.",
    "Birth control medication."
]

predictions=export_model.predict(examples)

# %%
for j in range(len(examples)):
    print(examples[j])
    prediction=predictions[j]
    for i, label in enumerate(raw_train_ds.class_names):
        print(label+':'+str(prediction[i]))

# %% [markdown]
# # Constipation relief
#
# Model predicts Bisacodyl:0.028075192
#
# Bisacodyl is a laxative. Good prediction!
#
# # Smoking cessation
#
# Model predicts Bupropion:0.028822651, Chantix:0.027415203, and Varenicline:0.027441071
#
# Bupropion, Chantix, and Varencline are all used to help people quit smoking.
#
# # Weight loss
#
# Model predicts Phentermine:0.025583226.
#
# Phentermine is used for weight loss, so this is a good choice. However, I would have also expected the model to predict Bupropion / Naltrexone (0.02402098) with a higher degree of confidence as it is the other weight loss medication in this list of 40 medications.
#
# # Birth control
#
# Model predicts Ethinyl estradiol :0.02980319
#
# Ethinyl Estradiol is the most commonly prescribed form of birth control medication so it makes sense that the model weighted this drug the highest. However, the model did not seem prefer the other birth control medications in this list (NuvaRing, Lo Loestrin FE

# %% [markdown]
# # Where can improvements be made?
